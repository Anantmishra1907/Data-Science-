# %% [markdown]
# <a href="https://colab.research.google.com/github/Anantmishra1907/Data-Science-/blob/main/imageclassifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Imported tensor flow

# %%
import tensorflow as tf
print("TensorFlow Version:", tf.__version__)
print("Keras Version:", tf.keras.__version__)
# Out:
# TensorFlow Version: 2.20.0
# Keras Version: 3.13.2

# %% [markdown]
# *Load A dataset *[link text](https://)

# %%
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train ,x_test = x_train/255.0 , x_test/255.0
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %% [markdown]
# Building a Machine learning model

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10)
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
predictions = model(x_train[:1]).numpy()
predictions
# Out:
# array([[ 0.45724508, -0.5426348 ,  0.90854853, -0.10065499, -0.92075014,
#         -0.07029381, -0.04482665,  0.10036552, -0.1961706 , -0.5004588 ]],
#       dtype=float32)

# %%
tf.nn.softmax(predictions).numpy()
# Out:
# array([[0.15239254, 0.05606882, 0.23931082, 0.08723099, 0.03841563,
#         0.08992004, 0.09223946, 0.10665295, 0.07928462, 0.05848416]],
#       dtype=float32)

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# %%
loss_fn(y_train[:1], predictions).numpy()
# Out:
# np.float32(2.4088345)

# %%
model.compile(optimizer='adam',
              loss=loss_fn,
              metrics=['accuracy'])

# %%
model.compile(optimizer='adam',
              loss=loss_fn,
              metrics=['accuracy'])
model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9155 - loss: 0.2923
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9588 - loss: 0.1407
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9681 - loss: 0.1054
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9725 - loss: 0.0866
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9764 - loss: 0.0753

# %%
model.evaluate(x_test,  y_test, verbose=2)
# Out:
# 313/313 - 1s - 3ms/step - accuracy: 0.9768 - loss: 0.0734
# [0.07343514263629913, 0.9768000245094299]
